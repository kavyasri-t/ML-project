# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
p,q=[],[]
x_train = []
y_train = []
x_test = []
y_test = []
df = pd.read_csv(r"C:\Users\Kavya\Downloads\INFY.NS.csv") # read csv file
#df=df.iloc[::-1].reset_index(drop=True)
df = df.dropna(how='any',axis=0)
rows = df.values.tolist()  # convert dataframe into a list
#rows.reverse()
data=rows[:]
data
for row in data:
    p.append(int(''.join(row[0].split('-'))))
    q.append(row[1])
#df.isnull().sum()
#x=df.loc[:,'High']
#y=df.loc[:,'Open']
x_train, x_test, y_train, y_test = train_test_split(p,q,train_size=0.9,test_size=0.1,random_state=42) # split training and test data

# Convert lists into numpy arrays 
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)


# reshape the values as we have only one input feature
x_train = x_train.reshape(-1,1)
x_test = x_test.reshape(-1,1)
clf_lr = LinearRegression()
clf_lr.fit(x_train,y_train)
y_pred_lr = clf_lr.predict(x_test)
#print(x_test)


f,(ax1,ax2) = plt.subplots(1,2,figsize=(30,10))
ax1.plot(df['Close'])

# Linear Regression
ax2.scatter(range(len(y_test)),y_test,color='red',label='data')
ax2.plot(range(len(y_test)),y_pred_lr,color='green',label='LR model')
#ax2.plot(y_test)
#ax2.plot(y_pred_lr)
ax1.legend()
Test_data = [[20050923]]
prediction = clf_lr.predict(Test_data)
print(prediction)
#print(q)
# Out:
# [157.19964701]
